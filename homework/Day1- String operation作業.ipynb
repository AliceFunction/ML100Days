# %% [markdown]
# # 作業目標：運用課程所學，操作字串達到預期輸出

# %% [markdown]
# ---

# %% [markdown]
# ## 讀入所需文件

# %%
import pandas as pd
#TSV文件有別於CSV的文件是使用\t作为分隔符，CSV則是使用,作为分隔符。
dataset = pd.read_csv(r'Restaurant_Reviews.tsv', sep='\t')

# %%
all_review = dataset['Review'].values

# %% [markdown]
# ---

# %% [markdown]
# ### 計算有多少個句子是以 . 結尾

# %%
n=0

for i in range(len(all_review)):
    if all_review[i].endswith('.'):
        n = n+1


print('There are {} sentences end with .'.format(n))
# Out:
# There are 819 sentences end with .

# %% [markdown]
# ### 將所有. 換成 ,

# %%
for i in range(len(all_review)):
    all_review[i] = all_review[i].replace('.',',')

# %% [markdown]
# ### 將所有sentence 中的 the 置換成 The

# %%
for i in range(len(all_review)):
    n = all_review[i].find('the ')
    all_review[i] = ''.join((all_review[i][:n],all_review[i][n:].replace('t','T',1)))

# %% [markdown]
# ### 將偶數句子全部轉換為大寫，基數句子全部轉換為小寫

# %%
for i in range(len(all_review)):
    if i%2==0:
        all_review[i] = all_review[i].upper()
    else:
        all_review[i] = all_review[i].lower()

# %% [markdown]
# ### 將所有句子合併在一起，並以' / ' 為間隔

# %%
'/'.join(all_review)
# Out:
# 'WOW,,, LOVED THIS PLA,/crust is not go,/NOT TASTY ANDTHE TEXTURE WAS JUST NAST,/stopped by duringthe late may bank holiday off rick steve recommendation and loved i,/THE SELECTION ONTHE MENU WAS GREAT AND SO WERE THE PRICE,/now i am getting angry and i want my damn p,/HONESLTY IT DIDN\'T TASTE THAT FRES)/the potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warm,/THE FRIES WERE GREAT T,/a great tou,/SERVICE WAS VERY PROM,/would not go ba,/THE CASHIER HAD NO CARE WHAT SO EVER ON WHAT I HAD TO SAY IT STILL ENDED UP BEING WAYYY OVERPRIC,/i triedthe cape cod ravoli, chicken, with cranberry,,,mmm!/I WAS DISGUSTED BECAUSE I WAS PRETTY SURE THAT WAS HUMAN HA,/i was shocked because no signs indicate cash on,/HIGHLY RECOMMEND,/waitress was a little slow in servi,/THIS PLACE IS NOT WORTH YOUR TIME, LET ALONE VEG,/did not like at a,/THE BURRITTOS BL!/the food, amazi,/SERVICE IS ALSO CU,/i could care less,,, the interior is just beautif,/SO THEY PERFORM,/that\'s right,,,the red velvet cake,,,,,ohhh this stuff is so goo,/- THEY NEVER BROUGHT A SALAD WE ASKED F,/this hole inthe wall has great mexican street tacos, and friendly staf,/TOOK AN HOUR TO GET OUR FOOD ONLY 4 TABLES IN RESTAURANT MY FOOD WAS LUKE WARM, OUR SEVER WAS RUNNING AROUND LIKE HE WAS TOTALLY OVERWHELM,/the worst wasthe salmon sashim,/ALSO THERE ARE